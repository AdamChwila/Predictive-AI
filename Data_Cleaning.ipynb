# %% [markdown]
# **Goal:**
# Transforming raw data into a format understandable for machine learning algorithms (numbers only, no empty values).

# %%
import pandas as pd
import numpy as np

# %%
data_small = [
    {"emp_id": 101, "gender": "Male", "department": "IT", "salary": 80000, "hire_date": "2019-01-15", "experience_years": 5, "age": 29},
    {"emp_id": 102, "gender": "Female", "department": "HR", "salary": np.nan, "hire_date": "2021-06-01", "experience_years": 2, "age": 34},
    {"emp_id": 103, "gender": "Male", "department": "Sales", "salary": 60000, "hire_date": "2023-01-10", "experience_years": np.nan, "age": 999}, # Outlier Age
    {"emp_id": 104, "gender": "Female", "department": "IT", "salary": 82000, "hire_date": "2015-03-20", "experience_years": 9, "age": 40},
    {"emp_id": 105, "gender": "Other", "department": "Sales", "salary": 55000, "hire_date": "2022-11-05", "experience_years": 1, "age": "twenty"} # Wrong type
]

# %%
df_small = pd.DataFrame(data_small)
print("--- SMALL DATASET ---")
display(df_small)
# Out:
# --- SMALL DATASET ---
#    emp_id  gender department   salary   hire_date  experience_years     age
# 0     101    Male         IT  80000.0  2019-01-15               5.0      29
# 1     102  Female         HR      NaN  2021-06-01               2.0      34
# 2     103    Male      Sales  60000.0  2023-01-10               NaN     999
# 3     104  Female         IT  82000.0  2015-03-20               9.0      40
# 4     105   Other      Sales  55000.0  2022-11-05               1.0  twenty

# %% [markdown]
# SLIDE 1 Data Cleaning

# %%
# Check types - note that 'age' is Object because of "twenty"
print(df_small.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   emp_id             5 non-null      int64
#  1   gender             5 non-null      object
#  2   department         5 non-null      object
#  3   salary             4 non-null      float64
#  4   hire_date          5 non-null      object
#  5   experience_years   4 non-null      float64
#  6   age                4 non-null      float64
#  7   salary_filled      5 non-null      float64
#  8   experience_filled  5 non-null      float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 492.0+ bytes
# None

# %%
# Fix 'age': Force numeric, errors='coerce' turns "twenty" into NaN
df_small['age'] = pd.to_numeric(df_small['age'], errors='coerce')
print("\nAfter type conversion:")
display(df_small)
# Out:
# After type conversion:
#    emp_id  gender department   salary   hire_date  experience_years    age  \
# 0     101    Male         IT  80000.0  2019-01-15               5.0   29.0
# 1     102  Female         HR      NaN  2021-06-01               2.0   34.0
# 2     103    Male      Sales  60000.0  2023-01-10               NaN  999.0
# 3     104  Female         IT  82000.0  2015-03-20               9.0   40.0
# 4     105   Other      Sales  55000.0  2022-11-05               1.0    NaN
#
#    salary_filled  experience_filled
# 0        80000.0                5.0
# 1        70000.0                2.0
# 2        60000.0                0.0
# 3        82000.0                9.0
# 4        55000.0                1.0

# %% [markdown]
# SLIDE 2 IMPUTATION STRATEGIES

# %%
# Salary: Fill with Median
median_salary = df_small['salary'].median()
df_small['salary_filled'] = df_small['salary'].fillna(median_salary)
df_small
# Out:
#    emp_id  gender department   salary   hire_date  experience_years    age  \
# 0     101    Male         IT  80000.0  2019-01-15               5.0   29.0
# 1     102  Female         HR      NaN  2021-06-01               2.0   34.0
# 2     103    Male      Sales  60000.0  2023-01-10               NaN  999.0
# 3     104  Female         IT  82000.0  2015-03-20               9.0   40.0
# 4     105   Other      Sales  55000.0  2022-11-05               1.0    NaN
#
#    salary_filled
# 0        80000.0
# 1        70000.0
# 2        60000.0
# 3        82000.0
# 4        55000.0

# %%
# Experience: Fill with 0
df_small['experience_filled'] = df_small['experience_years'].fillna(0)
df_small
# Out:
#    emp_id  gender department   salary   hire_date  experience_years    age  \
# 0     101    Male         IT  80000.0  2019-01-15               5.0   29.0
# 1     102  Female         HR      NaN  2021-06-01               2.0   34.0
# 2     103    Male      Sales  60000.0  2023-01-10               NaN  999.0
# 3     104  Female         IT  82000.0  2015-03-20               9.0   40.0
# 4     105   Other      Sales  55000.0  2022-11-05               1.0    NaN
#
#    salary_filled  experience_filled
# 0        80000.0                5.0
# 1        70000.0                2.0
# 2        60000.0                0.0
# 3        82000.0                9.0
# 4        55000.0                1.0

# %% [markdown]
# SLIDE 3 - HANDLING OUTLIERS

# %%
# Detect Outlier in Age (e.g., > 100)
outlier_mask = df_small['age'] > 100
print("Outliers detected:")
display(df_small[outlier_mask])

# Cap at 100
df_small.loc[df_small['age'] > 100, 'age'] = 100
display(df_small[['emp_id', 'age']])
# Out:
# Outliers detected:
#    emp_id gender department   salary   hire_date  experience_years    age  \
# 2     103   Male      Sales  60000.0  2023-01-10               NaN  999.0
#
#    salary_filled  experience_filled
# 2        60000.0                0.0
#    emp_id    age
# 0     101   29.0
# 1     102   34.0
# 2     103  100.0
# 3     104   40.0
# 4     105    NaN

# %% [markdown]
# SLIDE 4 - FEATURE ENGINEERING

# %%
# Convert to datetime
df_small['hire_date'] = pd.to_datetime(df_small['hire_date'])
df_small
# Out:
#    emp_id  gender department   salary  hire_date  experience_years    age  \
# 0     101    Male         IT  80000.0 2019-01-15               5.0   29.0
# 1     102  Female         HR      NaN 2021-06-01               2.0   34.0
# 2     103    Male      Sales  60000.0 2023-01-10               NaN  100.0
# 3     104  Female         IT  82000.0 2015-03-20               9.0   40.0
# 4     105   Other      Sales  55000.0 2022-11-05               1.0    NaN
#
#    salary_filled  experience_filled
# 0        80000.0                5.0
# 1        70000.0                2.0
# 2        60000.0                0.0
# 3        82000.0                9.0
# 4        55000.0                1.0

# %%
# Calculate Tenure (Days since hire)
now = pd.Timestamp.now()
df_small['tenure_days'] = (now - df_small['hire_date']).dt.days
display(df_small[['hire_date', 'tenure_days']])
# Out:
#    hire_date  tenure_days
# 0 2019-01-15         2504
# 1 2021-06-01         1636
# 2 2023-01-10         1048
# 3 2015-03-20         3901
# 4 2022-11-05         1114

# %% [markdown]
# SLIDE 5 - CATEGORY ENCODING

# %%
# One-Hot Encoding for Department
df_encoded = pd.get_dummies(df_small, columns=['department'], prefix='dept')
display(df_encoded[['emp_id', 'dept_HR', 'dept_IT', 'dept_Sales']])
# Out:
#    emp_id  dept_HR  dept_IT  dept_Sales
# 0     101    False     True       False
# 1     102     True    False       False
# 2     103    False    False        True
# 3     104    False     True       False
# 4     105    False    False        True

# %% [markdown]
# Now import the generated dirty file and clean it comprehensively.

# %%
# 1. Load Data
df_dirty = pd.read_csv('employees_dirty.csv')
print(f"Loaded rows: {len(df_dirty)}")
# Out:
# Loaded rows: 501

# %%
# 2. Quick Audit
print(df_dirty.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   emp_id            501 non-null    int64
#  1   gender            501 non-null    object
#  2   department        501 non-null    object
#  3   salary            457 non-null    float64
#  4   hire_date         501 non-null    object
#  5   experience_years  420 non-null    float64
#  6   age               501 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 27.5+ KB
# None

# %%
print(df_dirty.describe(include='all'))
# Out:
#             emp_id gender department        salary   hire_date  \
# count   501.000000    501        501  4.570000e+02         501
# unique         NaN      4          6           NaN         455
# top            NaN   Male  Marketing           NaN  2022-08-18
# freq           NaN    254        107           NaN           3
# mean    350.101796    NaN        NaN  7.937074e+04         NaN
# std     144.612211    NaN        NaN  2.313921e+05         NaN
# min     101.000000    NaN        NaN -1.103168e+04         NaN
# 25%     225.000000    NaN        NaN  5.750964e+04         NaN
# 50%     350.000000    NaN        NaN  6.680206e+04         NaN
# 75%     475.000000    NaN        NaN  7.738958e+04         NaN
# max     600.000000    NaN        NaN  5.000000e+06         NaN
#
#         experience_years  age
# count         420.000000  501
# unique               NaN   28
# top                  NaN   34
# freq                 NaN   54
# mean           11.304762  NaN
# ...

# %%
# Type cleaning
df_dirty['age'] = pd.to_numeric(df_dirty['age'], errors='coerce')
df_dirty
# Out:
#      emp_id  gender  department      salary   hire_date  experience_years  \
# 0       101  Female       Sales  5000000.00  2023-04-26               6.0
# 1       102    Male       Sales     -500.00  2022-08-03               NaN
# 2       103  Female       Sales    86192.21  2015-05-03              11.0
# 3       104    Male  Operations    83276.36  2015-04-19               NaN
# 4       105  Female  Operations    62190.16  2019-09-15               9.0
# ..      ...     ...         ...         ...         ...               ...
# 496     597  Female   Marketing    52553.05  2023-06-30               NaN
# 497     598  Female          IT    82144.92  2022-08-18              12.0
# 498     599  Female  Operations    54492.58  2022-11-22               8.0
# 499     600  Female       Sales    35430.01  2015-09-10              18.0
# 500     151    Male          IT    89861.26  2021-01-05              11.0
#
#        age
# 0     29.0
# 1     33.0
# 2    999.0
# 3     -1.0
# 4     34.0
# ...

# %%
# Type cleaning
df_dirty['hire_date'] = pd.to_datetime(df_dirty['hire_date'], errors='coerce')
df_dirty

# %%
# Category cleaning
df_dirty['gender'] = df_dirty['gender'].str.capitalize()
df_dirty

# %%
# Category cleaning
df_dirty['department'] = df_dirty['department'].str.strip()
df_dirty
# Out:
#      emp_id  gender  department      salary   hire_date  experience_years  \
# 0       101  Female       Sales  5000000.00  2023-04-26               6.0
# 1       102    Male       Sales     -500.00  2022-08-03               NaN
# 2       103  Female       Sales    86192.21  2015-05-03              11.0
# 3       104    Male  Operations    83276.36  2015-04-19               NaN
# 4       105  Female  Operations    62190.16  2019-09-15               9.0
# ..      ...     ...         ...         ...         ...               ...
# 496     597  Female   Marketing    52553.05  2023-06-30               NaN
# 497     598  Female          IT    82144.92  2022-08-18              12.0
# 498     599  Female  Operations    54492.58  2022-11-22               8.0
# 499     600  Female       Sales    35430.01  2015-09-10              18.0
# 500     151    Male          IT    89861.26  2021-01-05              11.0
#
#        age
# 0     29.0
# 1     33.0
# 2    999.0
# 3     -1.0
# 4     34.0
# ...

# %%
# Outliers
df_dirty = df_dirty[(df_dirty['salary'] > 0) & (df_dirty['salary'] < 1000000)]

# %%
# Imputation
df_dirty['salary'] = df_dirty['salary'].fillna(df_dirty['salary'].median())

# %%
# Check missing data
print(df_dirty.isna().sum())
# Out:
# emp_id               0
# gender               0
# department           0
# salary              44
# hire_date            0
# experience_years    81
# age                  2
# dtype: int64
